# %% [markdown]
# <a href="https://colab.research.google.com/github/sonu786786/Data-Analytics/blob/main/Python_Basics/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Basics

# %%
print("hello world")
# Out:
# hello world

# %%
# use of multiple lines:
# 1) use \n
print("hello world \nthis is my 1st program \ni hope you like it.")
# Out:
# hello world
# this is my 1st program
# i hope you like it.

# %%
# 2) use """ triple quotes """
print("""hello world
this is my 1st program
i hope you like it""")
# Out:
# hello world
# this is my 1st program
# i hope you like it

# %%
# single line comment

# %%
# Variables in Python
a = "hello"
print(a)
# Out:
# hello

# %%
# Rules for writting variables
# 1) case sensitive : A and a treated differently
# 2) not use space to create variable : instead of charging cable write charging_cable
# 3) should never start with a number of special symbols : instead of 1Num write Num1

# %%
# to take user inputs - by default it is string
name = input("Enter your name:")
print(name)
# Out:
# Enter your name:Sonu
# Sonu

# %%
# for numbers
age = int(input("enter your age:"))
print(age)
# Out:
# enter your age:21
# 21

# %%
# for decimal values
height = float(input("enter your height in feet: "))
print(height)
# Out:
# enter your height in feet: 5.8
# 5.8

# %%
# to do evaluation
exp1 = eval(input("enter any equation here: "))
print(exp1)
# Out:
# enter any equation here: 7+9
# 16

# %%
# TypeCasting
name = "Sonu"
print(type(name))
age = 21
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# datatype conversion
age = 21
print(type(age))
age = float(age)
print(type(age))
# Out:
# <class 'int'>
# <class 'float'>
