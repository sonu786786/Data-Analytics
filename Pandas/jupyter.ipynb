# %% [markdown]
# <a href="https://colab.research.google.com/github/sonu786786/Data-Analytics/blob/main/Pandas/jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas for Data Analysis

# %%
import pandas as pd
data = {"Name":["john","Peter","Lisa"],
        "Age": [25,28,31],
        "Salary": [30000,49000,89000]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Salary
# 0   john   25   30000
# 1  Peter   28   49000
# 2   Lisa   31   89000
